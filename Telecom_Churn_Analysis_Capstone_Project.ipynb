# %% [markdown]
# <a href="https://colab.research.google.com/github/its-amrita-sarkar-01/Telecommunication-Churning-1/blob/main/Telecom_Churn_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.pyplot import figure
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="white", palette=None)
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Telecom Churn.csv")

# %%
df.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  ...  Total intl charge  Customer service calls
# count     3333.000000  3333.000000  ...        3333.000000             3333.000000
# mean       101.064806   437.182418  ...           2.764581                1.562856
# std         39.822106    42.371290  ...           0.753773                1.315491
# min          1.000000   408.000000  ...           0.000000                0.000000
# 25%         74.000000   408.000000  ...           2.300000                1.000000
# 50%        101.000000   415.000000  ...           2.780000                1.000000
# 75%        127.000000   510.000000  ...           3.270000                2.000000
# max        243.000000   510.000000  ...           5.400000                9.000000
#
# [8 rows x 16 columns]

# %%
df.describe(include=["object", "bool"])
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3333
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2850

# %%
def dataoveriew(dataset, message):
    print(f'{message}:\n')
    print("Rows:", df.shape[0])
    print("\nNumber of features:", df.shape[1])
    print("\nFeatures:\n")
    print(df.columns.tolist())
    print("\nMissing values:", df.isnull().sum().values.sum())
    print("\nUnique values:")
    print(df.nunique())

# %%
dataoveriew(df, 'Overiew of the training dataset')
# Out:
# Overiew of the training dataset:
#
# Rows: 3333
#
# Number of features: 20
#
# Features:
#
# ['State', 'Account length', 'Area code', 'International plan', 'Voice mail plan', 'Number vmail messages', 'Total day minutes', 'Total day calls', 'Total day charge', 'Total eve minutes', 'Total eve calls', 'Total eve charge', 'Total night minutes', 'Total night calls', 'Total night charge', 'Total intl minutes', 'Total intl calls', 'Total intl charge', 'Customer service calls', 'Churn']
#
# Missing values: 0
#
# Unique values:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# ...

# %%
df_corr = df.corr()
df_corr
# Out:
#                         Account length  ...     Churn
# Account length                1.000000  ...  0.016541
# Area code                    -0.012463  ...  0.006174
# Number vmail messages        -0.004628  ... -0.089728
# Total day minutes             0.006216  ...  0.205151
# Total day calls               0.038470  ...  0.018459
# Total day charge              0.006214  ...  0.205151
# Total eve minutes            -0.006757  ...  0.092796
# Total eve calls               0.019260  ...  0.009233
# Total eve charge             -0.006745  ...  0.092786
# Total night minutes          -0.008955  ...  0.035493
# Total night calls            -0.013176  ...  0.006141
# Total night charge           -0.008960  ...  0.035496
# Total intl minutes            0.009514  ...  0.068239
# Total intl calls              0.020661  ... -0.052844
# Total intl charge             0.009546  ...  0.068259
# Customer service calls       -0.003796  ...  0.208750
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.heatmap(df_corr, vmin = -1, cmap='coolwarm', linecolor='white',  linewidths=.5, annot=True);

# %%
plt.figure(figsize=(20,10))
df.corr()['Churn'].sort_values(ascending = False).plot(kind='bar');

# %%
list(df.columns)
# Out:
# ['State',
#  'Account length',
#  'Area code',
#  'International plan',
#  'Voice mail plan',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
df.shape
# Out:
# (3333, 20)

# %%
df["Churn"] = df["Churn"].astype("int64")

# %%
df["Churn"].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
df["Churn"].mean()
# Out:
# 0.14491449144914492

# %%
_, axes = plt.subplots(1, 3, sharey=True, figsize=(20, 6))
sns.histplot(x = "Total day minutes", hue = 'Churn', kde = True, bins = 6, data = df, ax=axes[0])
sns.histplot(x = "Total eve minutes", hue = 'Churn', kde = True, bins = 6, data = df, ax=axes[1])
sns.histplot(x = "Total night minutes", hue = 'Churn', kde = True, bins = 6, data = df, ax=axes[2]);

# %%
_, axes = plt.subplots(1, 3, sharey=True, figsize=(20, 6))
sns.histplot(x = "Total day charge", hue = 'Churn', kde = True, bins = 6, data = df, ax=axes[0])
sns.histplot(x= "Total eve charge", hue = 'Churn', kde = True, bins = 6, data = df, ax=axes[1])
sns.histplot(x = "Total night charge", hue = 'Churn', kde = True, bins = 6, data = df, ax=axes[2]);

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3)
sns.kdeplot(df["Total day minutes"], shade=True, color="b",ax = ax1)
sns.kdeplot(df["Total eve minutes"], shade=True, color="r", ax = ax2)
sns.kdeplot(df["Customer service calls"], shade=True, color="g", ax = ax3)
fig.tight_layout()
plt.show(fig)

# %%
sns.catplot(
    x="Churn",
    y="Total day minutes",
    col="Customer service calls",
    data=df[df["Customer service calls"] < 5],
    kind="box",
    col_wrap=5,
    height=3,
    aspect=0.8,
);

# %%
colors = ['#4D3425','#E4512B']
contract_churn = df.groupby(['Customer service calls','Churn']).size().unstack()

ax = (contract_churn.T*100.0 / contract_churn.T.sum()).T.plot(kind='bar',
                                                                width = 0.6,
                                                                stacked = True,
                                                                rot = 0, 
                                                                figsize = (15,6),
                                                                color = colors)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.legend(loc='best',prop={'size':14},title = 'Churn')
ax.set_ylabel('% Customer service calls',size = 14)
ax.set_title('Churn by Customer service calls',size = 14)

# Code to add the data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0f}%'.format(height), (p.get_x()+.25*width, p.get_y()+.4*height),
                color = 'white',
               weight = 'bold',
               size = 14)

# %%
colors = ['#4D3425','#E4512B']
contract_churn = df.groupby(['International plan','Churn']).size().unstack()

ax = (contract_churn.T*100.0 / contract_churn.T.sum()).T.plot(kind='bar',
                                                                width = 0.4,
                                                                stacked = True,
                                                                rot = 0, 
                                                                figsize = (10,6),
                                                                color = colors)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.legend(loc='best',prop={'size':14},title = 'Churn')
ax.set_ylabel('% International plan',size = 14)
ax.set_title('Churn by International plan',size = 14)

# Code to add the data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0f}%'.format(height), (p.get_x()+.25*width, p.get_y()+.4*height),
                color = 'white',
               weight = 'bold',
               size = 14)

# %%
colors = ['#4D3425','#E4512B']
contract_churn = df.groupby(['Voice mail plan','Churn']).size().unstack()

ax = (contract_churn.T*100.0 / contract_churn.T.sum()).T.plot(kind='bar',
                                                                width = 0.4,
                                                                stacked = True,
                                                                rot = 0, 
                                                                figsize = (10,6),
                                                                color = colors)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.legend(loc='best',prop={'size':14},title = 'Churn')
ax.set_ylabel('% Voice mail plan',size = 14)
ax.set_title('Churn by Voice mail plan',size = 14)

# Code to add the data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate('{:.0f}%'.format(height), (p.get_x()+.25*width, p.get_y()+.4*height),
                color = 'white',
               weight = 'bold',
               size = 14)

# %%
colors = ['#4D3425','#E4512B']
ax = (df['Churn'].value_counts()*100.0 /len(df)).plot(kind='bar',stacked = True, rot = 0,
                                                                          color = colors,
                                                                         figsize = (8,6))
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('% Customers',size = 14)
ax.set_xlabel('Churn',size = 14)
ax.set_title('Churn Rate', size = 14)

# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_width())

# set individual bar lables using above list
total = sum(totals)

for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_x()+.15, i.get_height()-4.0, \
            str(round((i.get_height()/total), 1))+'%',
            fontsize=12,
            color='white',
           weight = 'bold',
           size = 14)

# %%
unique_states = df["State"].value_counts()
unique_states
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# VT     73
# ID     73
# MI     73
# UT     72
# TX     72
# IN     71
# KS     70
# MD     70
# NJ     68
# MT     68
# NC     68
# CO     66
# WA     66
# NV     66
# MS     65
# RI     65
# MA     65
# AZ     64
# MO     63
# FL     63
# ME     62
# NM     62
# ND     62
# OK     61
# NE     61
# DE     61
# SD     60
# SC     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# TN     53
# HI     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
print(df['State'].max())
print(df['State'].min())
# Out:
# WY
# AK

# %%
plt.figure(figsize=(18, 6))
plt.plot(unique_states)
plt.title('Unique States with Counts')
plt.ylabel('Counts')
plt.xlabel('States')
# Out:
# Text(0.5, 0, 'States')

# %%
def without_hue(plot, feature):
    total = len(feature)
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.3
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), size = 12)
    plt.show()

# %%
def with_hue(plot, feature, Number_of_categories, hue_categories):
    a = [p.get_height() for p in plot.patches]
    patch = [p for p in plot.patches]
    for i in range(Number_of_categories):
        total = feature.value_counts().values[i]
        for j in range(hue_categories):
            percentage = '{:.1f}%'.format(100 * a[(j*Number_of_categories + i)]/total)
            x = patch[(j*Number_of_categories + i)].get_x() + patch[(j*Number_of_categories + i)].get_width() / 2 - 0.15
            y = patch[(j*Number_of_categories + i)].get_y() + patch[(j*Number_of_categories + i)].get_height() 
            ax.annotate(percentage, (x, y), size = 12)
    plt.show()

# %%
plt.rcParams['figure.figsize'] = (25, 18)
ax = sns.countplot(x="State", palette="Set3", data = df)
#sns.countplot(df.State)
plt.title('Count of unique States', fontsize = 20)
plt.ylabel('Count', fontsize = 15)
plt.xlabel('Name of the States', fontsize = 15)
without_hue(ax, df.State);

# %%
df.groupby('Churn')['Customer service calls'].mean()
# Out:
# Churn
# 0    1.449825
# 1    2.229814
# Name: Customer service calls, dtype: float64

# %%
churn_in_states = df.groupby(['State','Churn'])['State'].count().unstack()

# %%
churn_in_states
# Out:
# Churn   0   1
# State
# AK     49   3
# AL     72   8
# AR     44  11
# AZ     60   4
# CA     25   9
# CO     57   9
# CT     62  12
# DC     49   5
# DE     52   9
# FL     55   8
# GA     46   8
# HI     50   3
# IA     41   3
# ID     64   9
# IL     53   5
# IN     62   9
# KS     57  13
# KY     51   8
# LA     47   4
# MA     54  11
# MD     53  17
# ME     49  13
# MI     57  16
# MN     69  15
# MO     56   7
# MS     51  14
# MT     54  14
# NC     57  11
# ND     56   6
# NE     56   5
# NH     47   9
# NJ     50  18
# NM     56   6
# NV     52  14
# NY     68  15
# OH     68  10
# OK     52   9
# OR     67  11
# PA     37   8
# RI     59   6
# SC     46  14
# SD     52   8
# TN     48   5
# TX     54  18
# UT     62  10
# VA     72   5
# VT     65   8
# WA     52  14
# WI     71   7
# WV     96  10
# WY     68   9

# %%
print(churn_in_states.max())
print(churn_in_states.min())
# Out:
# Churn
# 0    96
# 1    18
# dtype: int64
# Churn
# 0    25
# 1     3
# dtype: int64

# %%
churn_in_states.plot()
plt.rcParams['figure.figsize'] = (10, 6)
plt.title('Churn in different states')
plt.ylabel('Churn')
plt.xlabel('States')
# Out:
# Text(0.5, 0, 'States')

# %%
list(df.columns)
# Out:
# ['State',
#  'Account length',
#  'Area code',
#  'International plan',
#  'Voice mail plan',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
df.loc[0]
# Out:
# State                        KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         265.1
# Total day calls             110
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls              99
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls            91
# Total night charge        11.01
# Total intl minutes           10
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls        1
# Churn                         0
# Name: 0, dtype: object

# %%
df.head(5)
# Out:
#   State  Account length  ...  Customer service calls Churn
# 0    KS             128  ...                       1     0
# 1    OH             107  ...                       1     0
# 2    NJ             137  ...                       0     0
# 3    OH              84  ...                       2     0
# 4    OK              75  ...                       3     0
#
# [5 rows x 20 columns]

# %%
df['Total intl minutes'].max()
# Out:
# 20.0

# %%
list(df.columns)
# Out:
# ['State',
#  'Account length',
#  'Area code',
#  'International plan',
#  'Voice mail plan',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
df['Customer service calls'].value_counts()
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: Customer service calls, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (6,4)
sns.boxplot(df['Customer service calls']);

# %%
plt.rcParams['figure.figsize'] = (15, 10)
ax = sns.countplot(x ='Customer service calls', hue = 'Churn', data = df);
